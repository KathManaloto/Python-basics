# %% [markdown]
# # AMAZON WEB SCRAPER PROJECT

# %%
# IMPORT LIBRARIES
from bs4 import BeautifulSoup
import requests

import csv
import pandas as pd

import time
import datetime
import smtplib

# %%
# CONNECT TO WEBSITE AND PULL IN DATA
url = 'https://www.amazon.com/Shirt-Department-got-data/dp/B07PJL8NZ3/ref=sr_1_2?crid=M1KNERZCXA0M&dib=eyJ2IjoiMSJ9._VJx37ooceLPCJbeb7-8JMUBbamAYEUuagXU6kSUoP96YgQKbRzgrDLSxONE1YClnl5FrkvIy4EBjyBgIYpiu-maOyh0UXdS-vlOFRDo7dcIEHnrfsiCyLzooMSS22nJAg50jxJ0-qshWqvyg-L24AqRz4qAC-RXsR7Ipe0ASKXXq7y9PMdpzVE7al-CB28kkRi1X8CEKG2ZsVc5OKpxkf-_56YH3xugThV0hg_1A50UxQ1KBTkvnX8SIRBo5GUqnJi9TlG7sgYJtl9ZSf22uu9cR3KWm1CYs7OqJouwyto.KZB_P7qIIHGTagdfq-MLGm369m_251-k6EaHG-VfTaY&dib_tag=se&keywords=data%2Banalyst%2Btshirt%2Bgot%2Bdata&qid=1771000149&sprefix=data%2Banalyst%2Btshirt%2Bgot%2Bd%2Caps%2C361&sr=8-2&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
page = requests.get(url, headers = headers)

soup1 = BeautifulSoup(page.content, 'html.parser')
soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

# %%
# GET TITLE
title = soup2.find(id = 'productTitle').get_text().strip()
print(type(title))
print(title)
# Out:
# <class 'str'>
# got data? T-Shirt

# %%
# GET PRICE
whole = soup1.find('span', class_ = 'a-price-whole').get_text()
fraction = soup1.find('span', class_ = 'a-price-fraction').get_text()

price = float((whole + fraction).replace(',', ''))

print(type(price))
print(price)
# Out:
# <class 'float'>
# 1156.62

# %%
# PRINT PRICE AND TITLE
print(title)
print(price)
# Out:
# got data? T-Shirt
# 1156.62

# %% [markdown]
# #### DATETIME STAMP

# %%
# Create a Timestamp for THE output to track when data was collected
today = datetime.date.today()
print(today)
# Out:
# 2026-02-16

# %% [markdown]
# #### CREATE THE CSV AND IMPORT THE DATA TO THE CSV FILE

# %%
# Create CSV and write headers and data into the file
header = ['Title', 'Price', 'Date']
data = [title, price, today]

with open('AmazonWebScraperDataset.csv', 'w', newline = '', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
df = pd.read_csv(r"C:\Users\kathm\AmazonWebScraperDataset.csv")
print(df)
# Out:
#                Title    Price        Date
# 0  got data? T-Shirt  1156.62  2026-02-16
# 1  got data? T-Shirt  1156.62  2026-02-16
# 2  got data? T-Shirt  1156.62  2026-02-16
# 3  got data? T-Shirt  1156.62  2026-02-16
# 4  got data? T-Shirt  1156.62  2026-02-16

# %% [markdown]
# #### APPEND DATA TO THE CSV

# %%
#Append new data to the csv file
with open('AmazonWebScraperDataset.csv','a+',newline ='', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %% [markdown]
# #### PERFORM AUTOMATION

# %%
#Combine all of the above code into one function
def check_price():
    url = 'https://www.amazon.com/Shirt-Department-got-data/dp/B07PJL8NZ3/ref=sr_1_2?crid=M1KNERZCXA0M&dib=eyJ2IjoiMSJ9._VJx37ooceLPCJbeb7-8JMUBbamAYEUuagXU6kSUoP96YgQKbRzgrDLSxONE1YClnl5FrkvIy4EBjyBgIYpiu-maOyh0UXdS-vlOFRDo7dcIEHnrfsiCyLzooMSS22nJAg50jxJ0-qshWqvyg-L24AqRz4qAC-RXsR7Ipe0ASKXXq7y9PMdpzVE7al-CB28kkRi1X8CEKG2ZsVc5OKpxkf-_56YH3xugThV0hg_1A50UxQ1KBTkvnX8SIRBo5GUqnJi9TlG7sgYJtl9ZSf22uu9cR3KWm1CYs7OqJouwyto.KZB_P7qIIHGTagdfq-MLGm369m_251-k6EaHG-VfTaY&dib_tag=se&keywords=data%2Banalyst%2Btshirt%2Bgot%2Bdata&qid=1771000149&sprefix=data%2Banalyst%2Btshirt%2Bgot%2Bd%2Caps%2C361&sr=8-2&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    page = requests.get(url, headers = headers)

    soup1 = BeautifulSoup(page.content, 'html.parser')
    soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

    title = soup2.find(id = 'productTitle').get_text().strip()
    whole = soup1.find('span', class_ = 'a-price-whole').get_text()
    fraction = soup1.find('span', class_ = 'a-price-fraction').get_text()
    price = float((whole + fraction).replace(',', ''))

    today = datetime.date.today()

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]
    
    with open('AmazonWebScraperDataset.csv','a+',newline ='', encoding = 'UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
# Runs check_price after a set time and inputs data into the CSV file
while(True):
    check_price()
    time.sleep(5)

# %% [markdown]
# #### EMAIL NOTIFICATIONS

# %%
def send_mail():
    # Connect securely to Gmail SMTP server
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()

    # Login using dummy Gmail and app password
    server.login('sampleacct688@gmail.com','ouswpnkjeuexsabp')
    
    subject = "Demo Email from Python Script"
    body = "Hello! This is a safe demo email from a dummy account."
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'sampleacct688@gmail.com',
        'sampleacct688@gmail.com',
        msg
    )
     # Close the connection
    server.quit()
    print("Email sent successfully!")

# %%
# Call the function
send_mail()
# Out:
# Email sent successfully!
