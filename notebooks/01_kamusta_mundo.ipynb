# %% [markdown]
# # MY FIRST NOTEBOOK

# %% [markdown]
# ## Let's learn Python together!

# %%
print('Kamusta Mundo')
print('My name is Kat')
# Out:
# Kamusta Mundo
# My name is Kat

# %%
#We can move this cell

# %%
#We can duplicate it

# %%
#We can copy it and paste it elsewhere

# %%
#We can copy it and paste it elsewhere

# %%
#We can cut it and paste it elsewhere

# %%
#shutting down the kernel will stop its operation

# %%
#we need to restart it to run it again
