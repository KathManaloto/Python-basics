# %% [markdown]
# # READING IN FILES IN PANDAS

# %%
# import pandas library
import pandas as pd

# %%
# Read in CSV file
df = pd.read_csv(r"C:\Users\kathm\OneDrive\Desktop\DataAnalystBootCamp\Python\pandas\countries of the world.csv")
df

# %%
# Read in txt file
df = pd.read_csv(r"C:\Users\kathm\OneDrive\Desktop\DataAnalystBootCamp\Python\pandas\countries of the world.txt", sep = '\t')
df

# %%
# Read in txt file (Proper way)
df = pd.read_table(r"C:\Users\kathm\OneDrive\Desktop\DataAnalystBootCamp\Python\pandas\countries of the world.txt")
df

# %%
# Use read_table in reading .csv with a sepator
df = pd.read_table(r"C:\Users\kathm\OneDrive\Desktop\DataAnalystBootCamp\Python\pandas\countries of the world.csv", sep = ',')
df

# %%
# Read in json files
df = pd.read_json(r"C:\Users\kathm\OneDrive\Desktop\DataAnalystBootCamp\Python\pandas\json_sample.json")
df

# %%
# Read in excel files (1st sheet by default)
df = pd.read_excel(r"C:\Users\kathm\OneDrive\Desktop\DataAnalystBootCamp\Python\pandas\world_population_excel_workbook.xlsx")
df

# %%
# Read in excel file (all sheets)
df = pd.read_excel(r"C:\Users\kathm\OneDrive\Desktop\DataAnalystBootCamp\Python\pandas\world_population_excel_workbook.xlsx", sheet_name = None)
df

# %%
# Read in excel file (specific sheet)
df2 = pd.read_excel(r"C:\Users\kathm\OneDrive\Desktop\DataAnalystBootCamp\Python\pandas\world_population_excel_workbook.xlsx", sheet_name = 'Sheet1')
df2

# %%
# To show all rows and columns
pd.set_option("display.max.rows", None)
pd.set_option("display.max.columns", None)

# %% [markdown]
# #### Evaluate df2

# %%
# Show a summary of df2
df2.info()

# %%
# Show no. of rows and columns
df2.shape

# %%
# Show first 5 values (by default)
df2.head()

# %%
# Show specified no. of values
df2.head(10)

# %%
# Show last 5 values
df2.tail()

# %%
# Show last 10 values
df2.tail(10)

# %%
# Show specific column
df2['Rank']

# %%
# Show row in specific index
df2.loc[224]

# %%
# Show data in specific row and column
df2.loc[224, "Country"]
